# %%
import numpy as np
import pandas as pd
from ipywidgets import interact
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# %matplotlib notebook

# %%
Inst_df = pd.read_csv('/home/akhildp/workspace/my-ui/src/data/data-challenge-data-master/prod/user/sam/coaf/adhoc/tjy118/data/HMDA_Data/2012_to_2014_institutions_data.csv')

# %%
Loan_df = pd.read_csv('/home/akhildp/workspace/my-ui/src/data/data-challenge-data-master/prod/user/sam/coaf/adhoc/tjy118/data/HMDA_Data/2012_to_2014_loans_data.csv')
# Out:
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3,4,5,7,8,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Inst_df.columns
# Out:
# Index(['As_of_Year', 'Respondent_ID', 'Agency_Code', 'Respondent_Name_TS',
#        'Respondent_City_TS', 'Respondent_State_TS', 'Respondent_ZIP_Code',
#        'Parent_Name_TS', 'Parent_City_TS', 'Parent_State_TS',
#        'Parent_ZIP_Code', 'Assets_000_Panel'],
#       dtype='object')

# %%
Inst_df['U_ID'] = Inst_df['Respondent_ID'] + Inst_df['Agency_Code'].map(str)

# %%
len(Inst_df['Respondent_Name_TS'].unique())
# Out:
# 8740

# %%
Loan_df.columns
# Out:
# Index(['Agency_Code', 'Applicant_Income_000', 'As_of_Year',
#        'Census_Tract_Number', 'County_Code', 'FFIEC_Median_Family_Income',
#        'Loan_Amount_000', 'MSA_MD', 'Number_of_Owner_Occupied_Units',
#        'Respondent_ID', 'Sequence_Number', 'State_Code',
#        'Tract_to_MSA_MD_Income_Pct', 'MSA_MD_Description',
#        'Loan_Purpose_Description', 'Agency_Code_Description',
#        'Lien_Status_Description', 'Loan_Type_Description', 'State',
#        'County_Name', 'Conforming_Limit_000', 'Conventional_Status',
#        'Conforming_Status', 'Conventional_Conforming_Flag'],
#       dtype='object')

# %%
Loan_df['Respondent_ID']=Loan_df['Respondent_ID'].map(str)
Loan_df['Agency_Code']=Loan_df['Agency_Code'].map(str)

# %%
Inst_df['Respondent_ID']=Inst_df['Respondent_ID'].map(str)
Inst_df['Agency_Code']=Inst_df['Agency_Code'].map(str)

# %%
Inst_df[Inst_df['Respondent_ID']=='0000000047']
# Out:
#        As_of_Year Respondent_ID  Agency_Code        Respondent_Name_TS  \
# 0            2012    0000000047            1   FIRST FINANCIAL BANK NA
# 1664         2012    0000000047            3  TRADERS AND FARMERS BANK
# 7401         2013    0000000047            1   FIRST FINANCIAL BANK NA
# 8980         2013    0000000047            3    TRADERS & FARMERS BANK
# 14593        2014    0000000047            1   FIRST FINANCIAL BANK NA
# 16115        2014    0000000047            3  TRADERS AND FARMERS BANK
#
#       Respondent_City_TS Respondent_State_TS Respondent_ZIP_Code  \
# 0            TERRE HAUTE                  IN               47802
# 1664          HALEYVILLE                  AL               35565
# 7401         TERRE HAUTE                  IN               47802
# 8980          HALEYVILLE                  AL               35565
# 14593        TERRE HAUTE                  IN               47802
# 16115         HALEYVILLE                  AL               35565
#
# ...

# %%
Inst_df['Respondent_Name_TS'].unique()
# Out:
# array(['FIRST FINANCIAL BANK NA', 'FIRST FINANCIAL BANK, N.A.',
#        'FIRST NATIONAL BANK OF GERMANT', ..., 'ONEWEST BANK',
#        'DB PRIVATE WEALTH MORTGAGE', 'DISCOVER HOME LOANS, INC'], dtype=object)

# %%
len(Loan_ex_df) == len(Loan_df)
# Out:
# True

# %%
Inst_df[Inst_df['Respondent_ID']=='0000000384']
# Out:
#       As_of_Year Respondent_ID Agency_Code            Respondent_Name_TS  \
# 1703        2012    0000000384           3  THE OHIO VALLEY BANK COMPANY
#
#      Respondent_City_TS Respondent_State_TS Respondent_ZIP_Code  \
# 1703         GALLIPOLIS                  OH               45631
#
#              Parent_Name_TS Parent_City_TS Parent_State_TS Parent_ZIP_Code  \
# 1703  OHIO VALLEY BANC CORP     GALLIPOLIS              OH           45631
#
#       Assets_000_Panel
# 1703            793399

# %%
Loan_df[Loan_df['Respondent_ID']=='0000000384']
# Out:
#       Agency_Code Applicant_Income_000  As_of_Year Census_Tract_Number  \
# 0               3                 0084        2012             0207.00
# 1               3                 0084        2012             9556.00
# 2               3                 0053        2012             9556.00
# 3               3                 0085        2012             0206.01
# 4               3                 0038        2012             0107.01
# 5               3                 0113        2012             0206.05
# 6               3                 0091        2012             9555.00
# 7               3                 0025        2012             0121.00
# 8               3                 0111        2012             0019.02
# 9               3                 0070        2012             0206.05
# 10              3                 0048        2012             0206.04
# 11              3                 0068        2012             0201.00
# ...

# %%
Loan_ex_df[Loan_ex_df['Respondent_ID']=='619']
# Out:
# Empty DataFrame
# Columns: [Agency_Code, Applicant_Income_000, As_of_Year, Census_Tract_Number, County_Code, FFIEC_Median_Family_Income, Loan_Amount_000, MSA_MD, Number_of_Owner_Occupied_Units, Respondent_ID, Sequence_Number, State_Code, Tract_to_MSA_MD_Income_Pct, MSA_MD_Description, Loan_Purpose_Description, Agency_Code_Description, Lien_Status_Description, Loan_Type_Description, State, County_Name, Conforming_Limit_000, Conventional_Status, Conforming_Status, Conventional_Conforming_Flag, Respondent_Name_TS]
# Index: []
#
# [0 rows x 25 columns]

# %%
Loan_ex_df[['Respondent_ID','Agency_Code']][Loan_ex_df['Respondent_Name_TS'].isnull()]
# Out:
#         Respondent_ID Agency_Code
# 0          0000000384           3
# 1          0000000384           3
# 2          0000000384           3
# 3          0000000384           3
# 4          0000000384           3
# 5          0000000384           3
# 6          0000000384           3
# 7          0000000384           3
# 8          0000000384           3
# 9          0000000384           3
# 10         0000000384           3
# 11         0000000384           3
# 12         0000000384           3
# 13         0000000384           3
# 14         0000000384           3
# 15         0000000384           3
# 16         0000000384           3
# 17         0000000384           3
# 18         0000000384           3
# 19         0000000384           3
# 20         0000000384           3
# 21         0000000384           3
# 22         0000000785           5
# 23         0000000803           3
# 24         0000000803           3
# 25         0000000803           3
# ...

# %%
Missing_names=Loan_ex_df[['Respondent_ID','Agency_Code']][Loan_ex_df['Respondent_Name_TS'].isnull()].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-590e6ff0e6b0> in <module>()
# ----> 1 Missing_names=Loan_ex_df[['Respondent_ID','Agency_Code']][Loan_ex_df['Respondent_Name_TS'].isnull()].unique()
#       2 Missing_names['Respondent_ID']
#
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
def lookup(x):
    result=list(Resp_Name_df["Respondent_Name_TS"][Resp_Name_df['U_ID'] == str(x[0])+str(x[1])])[0]
    if result:
        return result[0]
    else:
        return "No Name Found"

# %%
list(Resp_Name_df["Respondent_Name_TS"][Resp_Name_df['U_ID'] == '00000000471'])[0]
# Out:
# 'FIRST FINANCIAL BANK NA'

# %%
Resp_Name_df=Inst_df[['Respondent_ID','Agency_Code','Respondent_Name_TS']]
Resp_Name_df=Resp_Name_df.drop_duplicates(subset=['Respondent_ID','Agency_Code'])

# %%
Resp_Name_df['U_ID']=Resp_Name_df['Respondent_ID'].map(str)+Resp_Name_df['Agency_Code'].map(str)

# %%
bool([])
# Out:
# False

# %%
Loan_df['Respondent_Name_TS']= Loan_df[['Respondent_ID','Agency_Code']].apply(lambda row:lookup(list(row)), axis=1)

# %%
New_df[['ad']]
# Out:
#                                ad
# 0         FIRST FINANCIAL BANK NA
# 1      FIRST FINANCIAL BANK, N.A.
# 2  FIRST NATIONAL BANK OF GERMANT
# 3  EXCHANGE NATIONAL BANK & TRUST
# 4   FIRST NATIONAL BANK AND TRUST

# %%
Loan_df[['Respondent_ID','Agency_Code']]
# Out:
#         Respondent_ID Agency_Code
# 0          0000000384           3
# 1          0000000384           3
# 2          0000000384           3
# 3          0000000384           3
# 4          0000000384           3
# 5          0000000384           3
# 6          0000000384           3
# 7          0000000384           3
# 8          0000000384           3
# 9          0000000384           3
# 10         0000000384           3
# 11         0000000384           3
# 12         0000000384           3
# 13         0000000384           3
# 14         0000000384           3
# 15         0000000384           3
# 16         0000000384           3
# 17         0000000384           3
# 18         0000000384           3
# 19         0000000384           3
# 20         0000000384           3
# 21         0000000384           3
# 22         0000000785           5
# 23         0000000803           3
# 24         0000000803           3
# 25         0000000803           3
# ...

# %%
Loan_ex_df = pd.merge(Loan_df,Resp_Name_df[['Respondent_Name_TS']], on=['Respondent_ID','Agency_Code'], how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Respondent_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
Loan_ex_df['Loan_Amount_000'].isnull().unique()
# Out:
# array([False], dtype=object)

# %%
Loan_ex_df[Loan_ex_df['Respondent_Name_TS'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Agency_Code, Applicant_Income_000, As_of_Year, Census_Tract_Number, County_Code, FFIEC_Median_Family_Income, Loan_Amount_000, MSA_MD, Number_of_Owner_Occupied_Units, Respondent_ID, Sequence_Number, State_Code, Tract_to_MSA_MD_Income_Pct, MSA_MD_Description, Loan_Purpose_Description, Agency_Code_Description, Lien_Status_Description, Loan_Type_Description, State, County_Name, Conforming_Limit_000, Conventional_Status, Conforming_Status, Conventional_Conforming_Flag, Respondent_Name_TS]
# Index: []
#
# [0 rows x 25 columns]

# %%
Loan_df[Loan_df['Respondent_ID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Agency_Code, Applicant_Income_000, As_of_Year, Census_Tract_Number, County_Code, FFIEC_Median_Family_Income, Loan_Amount_000, MSA_MD, Number_of_Owner_Occupied_Units, Respondent_ID, Sequence_Number, State_Code, Tract_to_MSA_MD_Income_Pct, MSA_MD_Description, Loan_Purpose_Description, Agency_Code_Description, Lien_Status_Description, Loan_Type_Description, State, County_Name, Conforming_Limit_000, Conventional_Status, Conforming_Status, Conventional_Conforming_Flag]
# Index: []
#
# [0 rows x 24 columns]

# %%
len(Loan_df)
# Out:
# 1321158

# %%
len(Loan_ex_df)
# Out:
# 1222854

# %%
Loan_df.columns
# Out:
# Index(['Agency_Code', 'Applicant_Income_000', 'As_of_Year',
#        'Census_Tract_Number', 'County_Code', 'FFIEC_Median_Family_Income',
#        'Loan_Amount_000', 'MSA_MD', 'Number_of_Owner_Occupied_Units',
#        'Respondent_ID', 'Sequence_Number', 'State_Code',
#        'Tract_to_MSA_MD_Income_Pct', 'MSA_MD_Description',
#        'Loan_Purpose_Description', 'Agency_Code_Description',
#        'Lien_Status_Description', 'Loan_Type_Description', 'State',
#        'County_Name', 'Conforming_Limit_000', 'Conventional_Status',
#        'Conforming_Status', 'Conventional_Conforming_Flag'],
#       dtype='object')

# %%
Loan_df['Loan_Type_Description'].unique()
# Out:
# array(['Conventional', 'FHA insured', 'VA guaranteed', 'FSA/RHS guaranteed'], dtype=object)

# %%
len(Inst_df.index)
# Out:
# 21655

# %%
len(Loan_df.index)
# Out:
# 1321158

# %%
Loan_df[0:5]
# Out:
#    Agency_Code Applicant_Income_000  As_of_Year Census_Tract_Number  \
# 0            3                 0084        2012             0207.00
# 1            3                 0084        2012             9556.00
# 2            3                 0053        2012             9556.00
# 3            3                 0085        2012             0206.01
# 4            3                 0038        2012             0107.01
#
#   County_Code FFIEC_Median_Family_Income  Loan_Amount_000 MSA_MD  \
# 0         079                   00054900               94  16620
# 1         043                   00054900              133  16620
# 2         043                   00054900               70  16620
# 3         079                   00054900              102  16620
# 4         039                   00054900              112  16620
#
#   Number_of_Owner_Occupied_Units Respondent_ID             ...               \
# 0                       00001545    0000000384             ...
# ...

# %%
len(Inst_df['U_ID'].unique()) == len(Inst_df['Respondent_Name_TS'].unique())
# Out:
# False

# %%
h=Loan_df[['Loan_Amount_000']].describe()

# %%
h
# Out:
#        Loan_Amount_000
# count      1321158.000
# mean           290.233
# std            965.779
# min              1.000
# 25%            153.000
# 50%            235.000
# 75%            347.000
# max          99625.000

# %%
Loan_df.groupby(['Loan_Type_Description'])['Loan_Amount_000'].describe()
# Out:
# Loan_Type_Description
# Conventional           count   929170.000
#                        mean       300.151
#                        std       1147.701
#                        min          1.000
#                        25%        148.000
#                        50%        234.000
#                        75%        351.000
#                        max      99625.000
# FHA insured            count   187725.000
#                        mean       231.899
#                        std        121.493
#                        min          2.000
#                        25%        148.000
#                        50%        206.000
#                        75%        287.000
#                        max       7000.000
# FSA/RHS guaranteed     count    24663.000
#                        mean       170.737
#                        std         68.602
#                        min         15.000
#                        25%        122.000
#                        50%        159.000
# ...

# %%
Loan_Amt_df=Loan_df[['Loan_Amount_000']]
Loan_Amt_df.sort_values(by='Loan_Amount_000', inplace=True)
# Out:
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
Loan_Amt_df['cum_sum'] = Loan_Amt_df.cumsum()
Loan_Amt_df['cum_sum'] = Loan_Amt_df['cum_sum']/sum(Loan_Amt_df['Loan_Amount_000'])
# Out:
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
Loan_Amt_df[Loan_Amt_df['cum_sum']>0.93]
# Out:
#          Loan_Amount_000  cum_sum
# 557719             12723    0.930
# 557610             12826    0.930
# 557886             12893    0.930
# 1320960            12896    0.930
# 1030646            12922    0.930
# 1321140            12930    0.930
# 557617             13000    0.930
# 1321087            13054    0.930
# 1030709            13088    0.930
# 1321103            13101    0.930
# 1030723            13105    0.930
# 1321138            13150    0.930
# 557857             13192    0.930
# 557757             13204    0.930
# 557867             13237    0.930
# 1320859            13264    0.931
# 1030738            13396    0.931
# 557742             13513    0.931
# 557788             13552    0.931
# 1321141            13583    0.931
# 557689             13604    0.931
# 1321027            13618    0.931
# 1030800            13665    0.931
# 1321157            13719    0.931
# 1030566            13748    0.931
# 1030648            13798    0.931
# ...

# %%
Loan_Amt_df.plot(x='Loan_Amount_000',y='cum_sum')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Loan_Amt_df['cum_sum']=Loan_Amt_df['cum_sum']/(Loan_Amt_df['Loan_Amount_000'].sum())
# Out:
# /home/akhildp/workspace/my-ui/venv/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
Loan_Amt_df[['Loan_Amount_000']].hist(bins=10, range=(1000,2000))
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c92209630>]], dtype=object)

# %%
Loan_Amt_df[['Loan_Amount_000']].hist(bins=10, range=(0,1000))
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c9213b4e0>]], dtype=object)

# %%
ser=Loan_Amt_df['Loan_Amount_000']
ser=ser.sort_values()
cum_dist = np.linspace(0.,1.,len(ser))
ser_cdf = pd.Series(cum_dist, index=ser)

# %%
cum_dist[-1000]
# Out:
# 0.99924384459984694

# %%
ser_cdf.plot(drawstyle='steps')
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
Loan_Amt_df.nlargest(50,columns='Loan_Amount_000')
# Out:
#          Loan_Amount_000
# 1320978            99625
# 1321003            99306
# 1321073            98285
# 557875             98279
# 1320882            97928
# 1320885            97757
# 1321069            96327
# 1320906            96257
# 1030811            96208
# 1320941            95985
# 557700             95415
# 557782             94742
# 1030767            94348
# 1030749            93786
# 557841             93768
# 557845             93463
# 1030612            93290
# 1321133            92712
# 557668             92620
# 557786             92601
# 1030602            92355
# 1321107            92158
# 1030812            91704
# 1030736            90609
# 557633             89963
# 1030627            89906
# 557589             89825
# 1320900            89275
# 557632             87473
# 557766             86582
# 1030592            86345
# 1321011            85220
# 557755             85071
# 1030707            85005
# 1320964            84944
# 557808             84120
# ...
